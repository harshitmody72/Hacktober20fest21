# %%
from array import *
from random import randint

def display(arr,n):
    for i in range(0,n):
        print(a[i], end =" ")
        
def bubble(arr,n):
  
    flag=0
    for i in range(0 , n-1):
        for j in range (0, n-i-1):
            if (a[j]>a[j+1]):
                a[j],a[j+1]=a[j+1],a[j]
                          
a=array("i",[])
i=0
while(i<10):
    a.insert(i,randint(0,20))
    i+=1
bubble(a,10)
print("Bubble Sort")
display(a,10)
# Out:
# Bubble Sort
# 1 4 10 10 11 13 17 17 17 17

# %%
from array import *
from random import randint

def display(arr,n):
    for i in range(0,n):
        print(a[i], end =" ")
        
def insert(arr,n):
    for i in range(1,n):
        temp=a[i]
        j=i-1
        while j>=0 and a[j]>temp:
                a[j+1]=a[j]
                j-=1
        a[j+1]=temp
        
        
a=array("i",[])
i=0
while(i<10):
    a.insert(i,randint(0,20))
    i+=1
display(a,10)
insert(a,10)

print("\n Array after Insertion sort")
display(a,10)
# Out:
# 7 5 19 11 20 13 4 16 14 12
#  Array after Insertion sort
# 4 5 7 11 12 13 14 16 19 20

# %%
from array import *
from random import randint

def display(arr,n):
    for i in range(0,n):
        print(a[i], end =" ")
        
def select(arr,n):
    for i in range(0, n-1):
        min=i
        for j in range(i+1,n):
            if a[j]<a[min]:
                min=j
                
        if (i!=min):
            temp=a[i]
            a[i]=a[min]
            a[min]=temp
        
        
a=array("i",[])
i=0
while(i<10):
    a.insert(i,randint(0,20))
    i+=1
print("Array before Sorting")
display(a,10)
select(a,10)

print("\nArray after Selection sorting")
display(a,10)
# Out:
# Array before Sorting
# 13 2 10 13 0 3 5 16 13 3
# Array after Selection sorting
# 0 2 3 3 5 10 13 13 13 16

# %%
from array import *
from random import randint

def display(arr,n):
    for i in range(0,n):
        print(arr[i], end =" ")
        
        
def merge(arr, l, m, r):
    n1 = m - l + 1
    n2 = r - m
 
    # create temp arrays
    L = [0] * (n1)
    R = [0] * (n2)
 
    # Copy data to temp arrays L[] and R[]
    for i in range(0, n1):
        L[i] = arr[l + i]
 
    for j in range(0, n2):
        R[j] = arr[m + 1 + j]
 
    # Merge the temp arrays back into arr[l..r]
    i = 0     # Initial index of first subarray
    j = 0     # Initial index of second subarray
    k = l     # Initial index of merged subarray
 
    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
 
    # Copy the remaining elements of L[], if there
    # are any
    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1
 
    # Copy the remaining elements of R[], if there
    # are any
    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1
            
    
def mergeSort(arr, l, r):
    if l < r:
 
        # Same as (l+r)//2, but avoids overflow for
        # large l and h
        m = l+(r-l)//2
 
        # Sort first and second halves
        mergeSort(arr, l, m)
        mergeSort(arr, m+1, r)
        merge(arr, l, m, r)

        
a=array("i",[])
i=0
while(i<10):
    a.insert(i,randint(0,20))
    i+=1
display(a,10)
mergeSort(a, 0, 9)

print("\n Array after merge sort")
display(a,10)
# Out:
# 9 9 20 18 2 12 0 16 12 9
#  Array after merge sort
# 0 2 9 9 9 12 12 16 18 20

# %%
from array import *
import math
from random import randint

def display(arr,n):
    for i in range(0,n):
        print(arr[i], end =" ")
        
def insertionSort(customList):
    for i in range(1, len(customList)):
        key = customList[i]
        j = i-1
        while j>=0 and key < customList[j]:
            customList[j+1] = customList[j]
            j -= 1
        customList[j+1] = key
    return customList


def bucket(customList):
    numberofBuckets = round(math.sqrt(len(customList)))
    maxValue = max(customList)
    arr = []

    for i in range(numberofBuckets):
        arr.append([])
    for j in customList:
        index_b = math.ceil(j*numberofBuckets/maxValue)
        arr[index_b-1].append(j)
    
    for i in range(numberofBuckets):
        arr[i] = insertionSort(arr[i])
    
    k = 0
    for i in range(numberofBuckets):
        for j in range(len(arr[i])):
            customList[k] = arr[i][j]
            k += 1
    return customList            
            
a=array("i",[])
i=0
while(i<10):
    a.insert(i,randint(0,20))
    i+=1
display(a,10)
print("\n Array after Bucket sort")
display(bucket(a),len(a))
# Out:
# 2 1 4 5 18 20 16 0 0 2
#  Array after Bucket sort
# 1 2 2 4 5 0 0 16 18 20

# %%
from array import *
from random import randint

def display(a,n):
    for i in range(0,n):
        print(a[i], end =" ")
        
def partition(a,low,high):
    i=low-1
    pivot=a[high]
    for j in range(low, high):
        if (a[j]<=pivot):
            i+=1
            a[i],a[j]=a[j],a[i]
    a[i+1],a[high]=a[high],a[i+1]
    return (i+1)
    
def QuickSort(a,low,high):
    if (low<high):
        p1=partition(a, low,high)
        QuickSort(a, low, p1-1)
        QuickSort(a,  p1+1, high)
    return a

a=array("i",[])
i=0
while(i<10):
    a.insert(i,randint(0,20))
    i+=1
display(a,10)
print()
a=QuickSort(a,0,9)
print("Array after Quick Sort ")
display(a,len(a))
# Out:
# 4 3 12 20 3 5 2 2 2 14
# Array after Quick Sort
# 2 2 2 3 3 4 5 12 14 20
